# %% [markdown]
# <a href="https://colab.research.google.com/github/Lanchenba-Mayanglambam/Data_Science-Amit-Sir/blob/main/lect_3_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# function
def fun_name(parameters):
  # body of the function

# %%
def sm(a,b):
  return a+b

print(sm(2,3))
# Out:
# 5

# %%
# lambda function
x = lambda a : 2*a
print(x(2))
# Out:
# 4

# %%
# upper(),lower(),title(),capitalize() function
st = ""
print(len(st))

st = "lanchenba singh"
# nm = st.upper()
# nm = st.lower()




# title() capitalize every starting element of a string
# nm = st.title()



# capitalize() capitalize only first starting element of a string
nm = st.capitalize()




print(st)
print(nm)
# Out:
# 0
# lanchenba singh
# Lanchenba singh

# %%
# strip() function removes spaces from beginning and ending
st = " Lanchenba Singh "
lt = st.strip()
# print(st)
# print(lt)



# lstrip() and rstrip() functions
a = "     today "
b = "     weather "
c = "      is GooD "


a = a.lstrip()
b = b.lstrip()
c = c.strip()

x = a+b+c
x = x.title()


# replcae() function replace the value with a new value and return a new value
x = x.replace("Good","Bad")

print(x)
# Out:
# Today Weather Is Bad

# %%
# find() function finds a particular value and return the index
a = "Today Weather Is Good"
y = ["hi","hello","superb"]
x = a.find("Good")
print(x)

b = y.index("hello")
print(b)
# Out:
# 17
# 1

# %%
# negative indexing in python
s = "hello world"

print(s[-5])


# slicing
print(s[6:11])
print(s[6: :])
# Out:
# w
# world
# world

# %%
# Set
# set by default sort the values
# set only store unique values
st = {2,23,2,1}
print(st)
# Out:
# {1, 2, 23}

# %%
# Dictonary
dct = {
    "name":"Lanchenba",
    "age":9,
    "role":"Student",
    "Address":"Kakching"
}
print(dct["name"])
# Out:
# Lanchenba
